# %%
# !pip install "etna[all]@git+https://github.com/etna-team/etna.git@master"
# !pip install sktime
# Out:
# Collecting etna@ git+https://github.com/etna-team/etna.git@master (from etna[all]@ git+https://github.com/etna-team/etna.git@master)
#   Cloning https://github.com/etna-team/etna.git (to revision master) to /tmp/pip-install-lp2q9hby/etna_e6cf3285fdbf41d68d4bee402fd5efbc
#   Running command git clone --filter=blob:none --quiet https://github.com/etna-team/etna.git /tmp/pip-install-lp2q9hby/etna_e6cf3285fdbf41d68d4bee402fd5efbc
#   Resolved https://github.com/etna-team/etna.git to commit 9cb5b3814489f4759ab68e62fc384ab248444a05
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: Bottleneck<2.0.0,>=1.3.4 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.4.2)
# Requirement already satisfied: Deprecated==1.2.13 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.2.13)
# Requirement already satisfied: boto3<2.0,>=1.5 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.37.23)
# Requirement already satisfied: botocore in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.37.23)
# Requirement already satisfied: catboost<2,>=1 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.2.7)
# Requirement already satisfied: dill<0.4.0,>=0.3.4 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.3.9)
# Requirement already satisfied: holidays>=0.40 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.69)
# Requirement already satisfied: hydra-slayer>=0.5 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.5.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.4.2)
# Requirement already satisfied: loguru>=0.7 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.7.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.10.0)
# Requirement already satisfied: numba>=0.53.1 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.60.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.26.4)
# Requirement already satisfied: omegaconf<3.0.0,>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.3.0)
# Requirement already satisfied: pandas<2.2.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.1.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (5.24.1)
# Requirement already satisfied: pmdarima>=2.0.4 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.0.4)
# Requirement already satisfied: ruptures<2.0.0,>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.1.9)
# Requirement already satisfied: scikit-learn<2,>=1.4 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.6.1)
# Requirement already satisfied: scipy<1.15,>=1.12 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.14.1)
# Requirement already satisfied: seaborn<1,>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.13.2)
# Requirement already satisfied: statsmodels<0.15,>=0.14 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.14.4)
# Requirement already satisfied: tbats<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.1.3)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.10.2)
# Requirement already satisfied: typer>=0.12 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.15.2)
# Requirement already satisfied: types-Deprecated==1.2.9 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.2.9)
# Requirement already satisfied: typing_extensions<5.0.0,>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (4.12.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated==1.2.13->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.17.2)
# Requirement already satisfied: accelerate<2,>=1 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.5.2)
# Requirement already satisfied: clearml<2.0,>=1.15 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.18.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.8.1)
# Requirement already satisfied: huggingface-hub>=0.23 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.29.3)
# Requirement already satisfied: jax<1,>0.4.28 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.5.2)
# Requirement already satisfied: jaxlib<1,>0.4.25 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.5.1)
# Requirement already satisfied: lightning in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.5.1)
# Requirement already satisfied: optuna<5,>=4 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (4.2.1)
# Requirement already satisfied: prophet<2.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.1.6)
# Requirement already satisfied: pyts<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.12.0)
# Requirement already satisfied: statsforecast<3,>=2 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.0.1)
# Requirement already satisfied: tensorboard<3.0.0,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.18.0)
# Requirement already satisfied: torch<3,>=2 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.6.0+cu124)
# Requirement already satisfied: transformers<5,>=4.42 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (4.50.0)
# Requirement already satisfied: tsfresh<0.21.0,>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.20.3)
# Requirement already satisfied: utilsforecast<1,>=0.1.10 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.2.12)
# Requirement already satisfied: wandb>=0.16 in /usr/local/lib/python3.11/dist-packages (from etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.19.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate<2,>=1->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate<2,>=1->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate<2,>=1->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate<2,>=1->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.5.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0,>=1.5->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0,>=1.5->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.11.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.3.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost<2,>=1->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.20.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost<2,>=1->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.17.0)
# Requirement already satisfied: attrs>=18.0 in /usr/local/lib/python3.11/dist-packages (from clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (25.3.0)
# Requirement already satisfied: furl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.1.4)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (4.23.0)
# Requirement already satisfied: pathlib2>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.3.7.post1)
# Requirement already satisfied: Pillow>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (11.1.0)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.2.1)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.11/dist-packages (from clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.32.3)
# Requirement already satisfied: pyjwt<2.10.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.9.0)
# Requirement already satisfied: referencing<0.40 in /usr/local/lib/python3.11/dist-packages (from clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.36.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2025.3.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (4.67.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax<1,>0.4.28->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax<1,>0.4.28->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.4.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.53.1->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.43.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf<3.0.0,>=2.1.1->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (4.9.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna<5,>=4->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna<5,>=4->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna<5,>=4->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.0.39)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.2.0,>=2.0.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.2.0,>=2.0.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2025.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.11/dist-packages (from pmdarima>=2.0.4->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.0.12)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.11/dist-packages (from pmdarima>=2.0.4->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (75.1.0)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet<2.0,>=1.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.2.5)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from prophet<2.0,>=1.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (6.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.4.8)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2,>=1.4->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.6.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from statsforecast<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.1.1)
# Requirement already satisfied: coreforecast>=0.0.12 in /usr/local/lib/python3.11/dist-packages (from statsforecast<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.0.15)
# Requirement already satisfied: fugue>=0.8.1 in /usr/local/lib/python3.11/dist-packages (from statsforecast<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.9.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels<0.15,>=0.14->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard<3.0.0,>=2.12.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard<3.0.0,>=2.12.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<3.0.0,>=2.12.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard<3.0.0,>=2.12.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (5.29.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<3.0.0,>=2.12.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<3.0.0,>=2.12.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.1.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.42->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.42->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.21.1)
# Requirement already satisfied: stumpy>=1.7.2 in /usr/local/lib/python3.11/dist-packages (from tsfresh<0.21.0,>=0.20.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.13.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.12->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.12->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.12->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (13.9.4)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (4.3.7)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.10.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.24.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.3.5)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from lightning->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.14.2)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from lightning->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.7.0)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.11/dist-packages (from lightning->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.5.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (9.0.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna<5,>=4->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.1.3)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from cmdstanpy>=1.0.4->prophet<2.0,>=1.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.5.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.11.14)
# Requirement already satisfied: triad>=0.9.7 in /usr/local/lib/python3.11/dist-packages (from fugue>=0.8.1->statsforecast<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.9.8)
# Requirement already satisfied: adagio>=0.2.4 in /usr/local/lib/python3.11/dist-packages (from fugue>=0.8.1->statsforecast<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.2.6)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from furl>=2.0.0->clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.16->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (4.0.12)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6.0->clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6.0->clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.23.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb>=0.16->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb>=0.16->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->clearml<2.0,>=1.15->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer>=0.12->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer>=0.12->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna<5,>=4->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<3.0.0,>=2.12.0->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.18.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.16->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (5.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (0.1.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (18.1.0)
# Requirement already satisfied: fs in /usr/local/lib/python3.11/dist-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (2.4.16)
# Requirement already satisfied: appdirs~=1.4.3 in /usr/local/lib/python3.11/dist-packages (from fs->triad>=0.9.7->fugue>=0.8.1->statsforecast<3,>=2->etna@ git+https://github.com/etna-team/etna.git@master->etna[all]@ git+https://github.com/etna-team/etna.git@master) (1.4.4)
# Requirement already satisfied: sktime in /usr/local/lib/python3.11/dist-packages (0.36.0)
# Requirement already satisfied: joblib<1.5,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from sktime) (1.4.2)
# Requirement already satisfied: numpy<2.3,>=1.21 in /usr/local/lib/python3.11/dist-packages (from sktime) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from sktime) (24.2)
# Requirement already satisfied: pandas<2.3.0,>=1.1 in /usr/local/lib/python3.11/dist-packages (from sktime) (2.1.4)
# Requirement already satisfied: scikit-base<0.13.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from sktime) (0.12.0)
# Requirement already satisfied: scikit-learn<1.7.0,>=0.24 in /usr/local/lib/python3.11/dist-packages (from sktime) (1.6.1)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in /usr/local/lib/python3.11/dist-packages (from sktime) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.1->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.1->sktime) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.1->sktime) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.7.0,>=0.24->sktime) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=1.1->sktime) (1.17.0)

# %%
import pandas as pd
from etna.datasets.tsdataset import TSDataset
import seaborn as sns
import matplotlib.pyplot as plt

from etna.models.nn import RNNModel
from etna.pipeline import Pipeline
from etna.models import CatBoostMultiSegmentModel, NaiveModel
from etna.metrics import MAE, MSE, SMAPE, MAPE
from etna.transforms import (LagTransform, MeanTransform, DifferencingTransform,
FourierTransform, LinearTrendTransform, LogTransform, STLTransform)

from etna.pipeline import Pipeline
import warnings

from ruptures.detection import Binseg
from etna.analysis import plot_forecast
from etna.analysis import (plot_backtest, acf_plot, cross_corr_plot, plot_trend, get_anomalies_median,
plot_periodogram, get_anomalies_density, find_change_points, plot_time_series_with_change_points, plot_anomalies)

# %%
target_df = pd.read_csv('ETHUSDT_1d.csv', delimiter=',')
regressor_df = pd.read_csv('BTCUSDT_1d.csv', delimiter=',')
# добавляем новый признак (разница между макс и мин ценой за день)
regressor_df['diff_ETH'] = target_df['high'] - target_df['low']
regressor_df = regressor_df.rename(columns={
    'open': 'open_BTC',
    'high': 'high_BTC',
    'low': 'low_BTC',
    'close': 'close_BTC',
    'volume': 'volume_BTC'
})
regressor_df['volume_ETH'] = target_df['volume']
target_df = target_df.drop('volume', axis=1)
# делаем лаги
for i in regressor_df.columns:
  if i != 'timestamp':
    regressor_df[f'lag_2_{i}'] = regressor_df[i].shift(2)
    regressor_df[f'{i}'] = regressor_df[i].shift(1)
target_df = target_df.loc[2:]
# делаем сегменты
segments = []
for feature in ['open', 'high', 'low', 'close']:
    temp = target_df[['timestamp', feature]].copy()
    temp['segment'] = f'main_{feature}'
    temp = temp.rename(columns={feature: 'target'})
    segments.append(temp)
target_df = pd.concat(segments)
# Оставляем место для прогноза на 20 дней
last_date = target_df['timestamp'].max()
cutoff_date = pd.to_datetime(last_date) - pd.Timedelta(days=20)
target_df = target_df[pd.to_datetime(target_df['timestamp']) <= cutoff_date]
# Оставляем только нужные колонки
regressor_df = regressor_df[['timestamp'] + [col for col in regressor_df.columns if col not in ['timestamp', 'segment']]]
# Дублируем регрессоры для всех сегментов
segments_list = target_df['segment'].unique()
regressor_list = []
for segment in segments_list:
    temp = regressor_df.copy()
    temp['segment'] = segment
    regressor_list.append(temp)

regressor_df = pd.concat(regressor_list)
ts = TSDataset(df=target_df, freq="D", df_exog=regressor_df, known_future="all")
print("Сегменты:", ts.segments)
print()
display(ts)
# Out:
# Сегменты: ['main_close', 'main_high', 'main_low', 'main_open']
# segment    main_close                                                    \
# feature     close_BTC diff_ETH  high_BTC lag_2_close_BTC lag_2_diff_ETH
# timestamp
# 2017-08-19    4108.37    27.85   4371.52         4285.08          14.18
# 2017-08-20    4139.98    21.90   4184.69         4108.37          27.85
# 2017-08-21    4086.29    17.68   4211.08         4139.98          21.90
# 2017-08-22    4016.00    51.92   4119.62         4086.29          17.68
# 2017-08-23    4040.00   186.20   4104.82         4016.00          51.92
# ...               ...      ...       ...             ...            ...
# 2025-02-18   95780.00   211.99  97046.59        96118.12          76.05
# 2025-02-19   95671.74   151.49  96753.91        95780.00         211.99
# 2025-02-20   96644.37    80.67  96899.99        95671.74         151.49
# 2025-02-21   98305.00    63.41  98711.36        96644.37          80.67
# 2025-02-22   96181.98   228.60  99475.00        98305.00          63.41
#
# segment                                                                  \
# feature    lag_2_high_BTC lag_2_low_BTC lag_2_open_BTC lag_2_volume_BTC
# timestamp
# 2017-08-19        4485.39       4200.74        4261.48       795.150377
# 2017-08-20        4371.52       3938.77        4285.08      1199.888264
# 2017-08-21        4184.69       3850.00        4108.37       381.309763
# 2017-08-22        4211.08       4032.62        4120.98       467.083022
# 2017-08-23        4119.62       3911.79        4069.13       691.743060
# ...                   ...           ...            ...              ...
# 2025-02-18       97704.47      96046.18       97569.67      8191.424900
# 2025-02-19       97046.59      95205.00       96118.12     16492.045100
# 2025-02-20       96753.91      93388.09       95780.01     23368.194710
# 2025-02-21       96899.99      95029.99       95671.74     16438.509540
# 2025-02-22       98711.36      96415.09       96644.37     17057.391770
#
# segment                      ...      main_open                               \
# feature    lag_2_volume_ETH  ... lag_2_high_BTC lag_2_low_BTC lag_2_open_BTC
# timestamp                    ...
# 2017-08-19       7030.71034  ...        4485.39       4200.74        4261.48
# 2017-08-20       9537.84646  ...        4371.52       3938.77        4285.08
# 2017-08-21       2146.19773  ...        4184.69       3850.00        4108.37
# 2017-08-22       2510.13871  ...        4211.08       4032.62        4120.98
# 2017-08-23       5219.44542  ...        4119.62       3911.79        4069.13
# ...                     ...  ...            ...           ...            ...
# 2025-02-18     191231.53140  ...       97704.47      96046.18       97569.67
# 2025-02-19     639739.81970  ...       97046.59      95205.00       96118.12
# 2025-02-20     604863.87370  ...       96753.91      93388.09       95780.01
# 2025-02-21     326154.02020  ...       96899.99      95029.99       95671.74
# 2025-02-22     336735.25440  ...       98711.36      96415.09       96644.37
#
# segment                                                                    \
# feature    lag_2_volume_BTC lag_2_volume_ETH   low_BTC  open_BTC   target
# timestamp
# 2017-08-19       795.150377       7030.71034   3938.77   4285.08   293.31
# 2017-08-20      1199.888264       9537.84646   3850.00   4108.37   289.41
# 2017-08-21       381.309763       2146.19773   4032.62   4120.98   299.10
# 2017-08-22       467.083022       2510.13871   3911.79   4069.13   321.04
# 2017-08-23       691.743060       5219.44542   3400.00   4016.00   312.25
# ...                     ...              ...       ...       ...      ...
# 2025-02-18      8191.424900     191231.53140  95205.00  96118.12  2744.05
# 2025-02-19     16492.045100     639739.81970  93388.09  95780.01  2672.00
# 2025-02-20     23368.194710     604863.87370  95029.99  95671.74  2715.51
# 2025-02-21     16438.509540     326154.02020  96415.09  96644.37  2738.04
# 2025-02-22     17057.391770     336735.25440  94871.95  98305.01  2663.00
#
# segment
# feature       volume_BTC    volume_ETH
# timestamp
# 2017-08-19   1199.888264    9537.84646
# 2017-08-20    381.309763    2146.19773
# 2017-08-21    467.083022    2510.13871
# 2017-08-22    691.743060    5219.44542
# 2017-08-23    966.684858    7956.35088
# ...                  ...           ...
# 2025-02-18  16492.045100  639739.81970
# 2025-02-19  23368.194710  604863.87370
# 2025-02-20  16438.509540  326154.02020
# 2025-02-21  17057.391770  336735.25440
# 2025-02-22  32249.281400  890440.06040
#
# [2745 rows x 60 columns]

# %%
print('Таргеты')
ts.plot(column="target", n_segments=5)
# Out:
# Таргеты

# %%
print('Регрессоры')
ts.plot(column="close_BTC", n_segments=1)
ts.plot(column="high_BTC", n_segments=1)
ts.plot(column="low_BTC", n_segments=1)
ts.plot(column="open_BTC", n_segments=1)
ts.plot(column="volume_BTC", n_segments=1)
ts.plot(column="volume_ETH", n_segments=1)
ts.plot(column="diff_ETH", n_segments=1)
# Out:
# Регрессоры

# %%
acf_plot(ts, lags=21)

# %%
acf_plot(ts, lags=21, partial=True)

# %%
cross_corr_plot(ts, maxlags=20)

# %%
plot_periodogram(ts, period=365.2425, amplitude_aggregation_mode="per-segment", xticks=[1, 2, 4, 6, 12, 26])

# %%
anomaly_dict = get_anomalies_median(ts, window_size=100)
plot_anomalies(ts, anomaly_dict)

# %%
change_points = find_change_points(ts=ts, in_column="target", change_point_model=Binseg(), pen=1e7)
plot_time_series_with_change_points(ts=ts, change_points=change_points)

# %%
train_ts, test_ts = ts.train_test_split(test_size = 20)

# %%
HORIZON = 20
model = NaiveModel(lag=20)
model.fit(train_ts)
# Out:
# /usr/local/lib/python3.11/dist-packages/etna/models/seasonal_ma.py:64: UserWarning: This model doesn't work with exogenous features. Columns {'low_BTC', 'high_BTC', 'lag_2_low_BTC', 'volume_BTC', 'volume_ETH', 'lag_2_volume_BTC', 'lag_2_close_BTC', 'lag_2_high_BTC', 'open_BTC', 'close_BTC', 'diff_ETH', 'lag_2_diff_ETH', 'lag_2_volume_ETH', 'lag_2_open_BTC'} won't be used.
#   warnings.warn(
# NaiveModel(lag = 20, )

# %%
future_ts = train_ts.make_future(future_steps=HORIZON, tail_steps=model.context_size)
forecast_ts = model.forecast(future_ts, prediction_size=HORIZON)

# %%
mape = MAPE()

# %%
mape(y_true=test_ts, y_pred=forecast_ts)
# Out:
# {'main_close': 20.298283784600972,
#  'main_high': 20.859115166228626,
#  'main_low': 21.72564720587246,
#  'main_open': 20.572430134347265}

# %%
plot_forecast(forecast_ts, test_ts, train_ts, n_train_samples=36)

# %%
ts
# Out:
# segment    main_close                                                    \
# feature     close_BTC diff_ETH  high_BTC lag_2_close_BTC lag_2_diff_ETH
# timestamp
# 2017-08-19    4108.37    27.85   4371.52         4285.08          14.18
# 2017-08-20    4139.98    21.90   4184.69         4108.37          27.85
# 2017-08-21    4086.29    17.68   4211.08         4139.98          21.90
# 2017-08-22    4016.00    51.92   4119.62         4086.29          17.68
# 2017-08-23    4040.00   186.20   4104.82         4016.00          51.92
# ...               ...      ...       ...             ...            ...
# 2025-02-18   95780.00   211.99  97046.59        96118.12          76.05
# 2025-02-19   95671.74   151.49  96753.91        95780.00         211.99
# 2025-02-20   96644.37    80.67  96899.99        95671.74         151.49
# 2025-02-21   98305.00    63.41  98711.36        96644.37          80.67
# 2025-02-22   96181.98   228.60  99475.00        98305.00          63.41
#
# segment                                                                  \
# feature    lag_2_high_BTC lag_2_low_BTC lag_2_open_BTC lag_2_volume_BTC
# timestamp
# 2017-08-19        4485.39       4200.74        4261.48       795.150377
# 2017-08-20        4371.52       3938.77        4285.08      1199.888264
# 2017-08-21        4184.69       3850.00        4108.37       381.309763
# 2017-08-22        4211.08       4032.62        4120.98       467.083022
# 2017-08-23        4119.62       3911.79        4069.13       691.743060
# ...                   ...           ...            ...              ...
# 2025-02-18       97704.47      96046.18       97569.67      8191.424900
# 2025-02-19       97046.59      95205.00       96118.12     16492.045100
# 2025-02-20       96753.91      93388.09       95780.01     23368.194710
# 2025-02-21       96899.99      95029.99       95671.74     16438.509540
# 2025-02-22       98711.36      96415.09       96644.37     17057.391770
#
# segment                      ...      main_open                               \
# feature    lag_2_volume_ETH  ... lag_2_high_BTC lag_2_low_BTC lag_2_open_BTC
# timestamp                    ...
# 2017-08-19       7030.71034  ...        4485.39       4200.74        4261.48
# 2017-08-20       9537.84646  ...        4371.52       3938.77        4285.08
# 2017-08-21       2146.19773  ...        4184.69       3850.00        4108.37
# 2017-08-22       2510.13871  ...        4211.08       4032.62        4120.98
# 2017-08-23       5219.44542  ...        4119.62       3911.79        4069.13
# ...                     ...  ...            ...           ...            ...
# 2025-02-18     191231.53140  ...       97704.47      96046.18       97569.67
# 2025-02-19     639739.81970  ...       97046.59      95205.00       96118.12
# 2025-02-20     604863.87370  ...       96753.91      93388.09       95780.01
# 2025-02-21     326154.02020  ...       96899.99      95029.99       95671.74
# 2025-02-22     336735.25440  ...       98711.36      96415.09       96644.37
#
# segment                                                                    \
# feature    lag_2_volume_BTC lag_2_volume_ETH   low_BTC  open_BTC   target
# timestamp
# 2017-08-19       795.150377       7030.71034   3938.77   4285.08   293.31
# 2017-08-20      1199.888264       9537.84646   3850.00   4108.37   289.41
# 2017-08-21       381.309763       2146.19773   4032.62   4120.98   299.10
# 2017-08-22       467.083022       2510.13871   3911.79   4069.13   321.04
# 2017-08-23       691.743060       5219.44542   3400.00   4016.00   312.25
# ...                     ...              ...       ...       ...      ...
# 2025-02-18      8191.424900     191231.53140  95205.00  96118.12  2744.05
# 2025-02-19     16492.045100     639739.81970  93388.09  95780.01  2672.00
# 2025-02-20     23368.194710     604863.87370  95029.99  95671.74  2715.51
# 2025-02-21     16438.509540     326154.02020  96415.09  96644.37  2738.04
# 2025-02-22     17057.391770     336735.25440  94871.95  98305.01  2663.00
#
# segment
# feature       volume_BTC    volume_ETH
# timestamp
# 2017-08-19   1199.888264    9537.84646
# 2017-08-20    381.309763    2146.19773
# 2017-08-21    467.083022    2510.13871
# 2017-08-22    691.743060    5219.44542
# 2017-08-23    966.684858    7956.35088
# ...                  ...           ...
# 2025-02-18  16492.045100  639739.81970
# 2025-02-19  23368.194710  604863.87370
# 2025-02-20  16438.509540  326154.02020
# 2025-02-21  17057.391770  336735.25440
# 2025-02-22  32249.281400  890440.06040
#
# [2745 rows x 60 columns]

# %%
from etna.transforms import (
    ChangePointsLevelTransform,
    ChangePointsTrendTransform,
    DifferencingTransform,
    LagTransform,
    TheilSenTrendTransform,
    StdTransform,
    MinTransform,
    MaxTransform
)
warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)

log = LogTransform(in_column="target", inplace=True)
stl = STLTransform(
    in_column = "target",
    period = 7,
    robust = True
)
lags = LagTransform(in_column="target", lags=list(range(HORIZON, 23)), out_column="lag")
mean = MeanTransform(in_column=f"lag_{HORIZON}", window=7, out_column="mean")
std = StdTransform(in_column=f"lag_{HORIZON}", window=7, out_column="std")
CPTI = ChangePointsTrendTransform(in_column="target")
transforms = [log, stl, CPTI, lags, std, mean]
display(transforms)
print()

model = CatBoostMultiSegmentModel(
  iterations=1000,
  learning_rate=0.01,
  depth=8,
  loss_function='MAPE',
  # l2_leaf_reg=2
)
pipeline = Pipeline(model=model, horizon=3, transforms=transforms)
metrics_df, forecast_df, fold_info_df = pipeline.backtest(ts=ts, metrics=[MAE(), MAPE()], n_folds=10)
print()
print('MAPE_avg', metrics_df.MAPE.shape)
print('close: ', metrics_df.MAPE.iloc[:10].mean())
print('high: ', metrics_df.MAPE.iloc[10:20].mean())
print('low: ', metrics_df.MAPE.iloc[20:30].mean())
print('open: ', metrics_df.MAPE.iloc[30:40].mean())
print('AVG_metrics: ', metrics_df.MAPE.mean())

plot_backtest(forecast_df, ts, history_len=100)
# Out:
# [LogTransform(in_column = 'target', base = 10, inplace = True, out_column = None, ),
#  STLTransform(in_column = 'target', period = 7, model = 'arima', robust = True, model_kwargs = None, stl_kwargs = None, ),
#  ChangePointsTrendTransform(in_column = 'target', change_points_model = RupturesChangePointsModel(change_points_model = <ruptures.detection.binseg.Binseg object at 0x7b776a776850>, n_bkps = 5, ), per_interval_model = SklearnRegressionPerIntervalModel(model = LinearRegression(), ), ),
#  LagTransform(in_column = 'target', lags = [20, 21, 22], out_column = 'lag', ),
#  StdTransform(in_column = 'lag_20', window = 7, seasonality = 1, min_periods = 1, fillna = 0, out_column = 'std', ddof = 1, ),
#  MeanTransform(in_column = 'lag_20', window = 7, seasonality = 1, alpha = 1, min_periods = 1, fillna = 0, out_column = 'mean', )]
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:   47.7s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=1)]: Done   6 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=1)]: Done   7 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=1)]: Done   8 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=1)]: Done   9 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=1)]: Done  10 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=1)]: Done  10 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=1)]: Done   6 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=1)]: Done   7 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=1)]: Done   8 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=1)]: Done   9 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=1)]: Done  10 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=1)]: Done  10 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   6 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   7 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   8 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   9 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  10 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  10 tasks      | elapsed:    0.3s
# MAPE_avg (40,)
# close:  3.8392240469414247
# high:  4.11023927479535
# low:  5.624105267906276
# open:  3.770034026983692
# AVG_metrics:  4.335900654156686

# %%
from etna.models import AutoARIMAModel

warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)
log = LogTransform(in_column="target", inplace=True)
stl = STLTransform(
    in_column="target",
    period=2,
    robust=True
)
diff = DifferencingTransform(in_column="target", out_column="diff", order=1)
transforms = [log, stl, ]
display(transforms)
print()

model = AutoARIMAModel()

pipeline = Pipeline(model=model, horizon=3, transforms=transforms)
metrics_df, forecast_df, fold_info_df = pipeline.backtest(ts=ts, metrics=[MAE(), MAPE()], n_folds=15)

print()
print('MAPE_avg', metrics_df.MAPE.shape)
print('close: ', metrics_df.MAPE.iloc[:15].mean())
print('high: ', metrics_df.MAPE.iloc[15:30].mean())
print('low: ', metrics_df.MAPE.iloc[30:45].mean())
print('open: ', metrics_df.MAPE.iloc[45:60].mean())
print('AVG_metrics: ', metrics_df.MAPE.mean())

plot_backtest(forecast_df, ts, history_len=100)
# Out:
# [LogTransform(in_column = 'target', base = 10, inplace = True, out_column = None, ),
#  STLTransform(in_column = 'target', period = 2, model = 'arima', robust = True, model_kwargs = None, stl_kwargs = None, )]
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=1)]: Done   6 tasks      | elapsed: 20.0min
# [Parallel(n_jobs=1)]: Done   7 tasks      | elapsed: 23.3min
# [Parallel(n_jobs=1)]: Done   8 tasks      | elapsed: 26.7min
# [Parallel(n_jobs=1)]: Done   9 tasks      | elapsed: 30.1min
# [Parallel(n_jobs=1)]: Done  10 tasks      | elapsed: 33.4min
# [Parallel(n_jobs=1)]: Done  11 tasks      | elapsed: 36.8min
# [Parallel(n_jobs=1)]: Done  12 tasks      | elapsed: 40.1min
# [Parallel(n_jobs=1)]: Done  13 tasks      | elapsed: 43.6min
# [Parallel(n_jobs=1)]: Done  14 tasks      | elapsed: 47.0min
# [Parallel(n_jobs=1)]: Done  15 tasks      | elapsed: 50.3min
# [Parallel(n_jobs=1)]: Done  15 tasks      | elapsed: 50.3min
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=1)]: Done   6 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=1)]: Done   7 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=1)]: Done   8 tasks      | elapsed:   42.0s
# [Parallel(n_jobs=1)]: Done   9 tasks      | elapsed:   47.7s
# [Parallel(n_jobs=1)]: Done  10 tasks      | elapsed:   52.5s
# [Parallel(n_jobs=1)]: Done  11 tasks      | elapsed:   57.6s
# [Parallel(n_jobs=1)]: Done  12 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=1)]: Done  13 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=1)]: Done  14 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=1)]: Done  15 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=1)]: Done  15 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   6 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   7 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   8 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   9 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  10 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  11 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  12 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  13 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  14 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  15 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done  15 tasks      | elapsed:    0.4s
# MAPE_avg (60,)
# close:  3.726205539658896
# high:  3.7917123582908894
# low:  5.187832567135984
# open:  3.8173461886294437
# AVG_metrics:  4.130774163428803

# %%
model.get_model()
